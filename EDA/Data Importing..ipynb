# %%
import pandas as pd

# Specify the file path
file_path = '/home/borna/DC/DCIAProject/Data/jads_data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
# /tmp/ipykernel_171534/3792315379.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#                global_id chunk_name  \
# 0       9300000080997844    T-shirt
# 1       9300000050432315    T-shirt
# 2       9300000091408544    T-shirt
# 3       9300000096674994    T-shirt
# 4       9300000009329806    T-shirt
# ...                  ...        ...
# 132966  9300000156249749    T-shirt
# 132967  9300000157260599    T-shirt
# 132968  9300000159180993    T-shirt
# 132969  9300000033244003    T-shirt
# 132970  9300000133978780    T-shirt
#
#                                                     title  \
# 0       Craft Community Mix SS Tee W 1907389 - Bright ...
# 1          Basics t-shirt wit voor Jongens | Maat 170/176
# 2          BASE LEVEL Yolanda Top - Light Beige - maat 48
# 3       Vila T-shirt Vipaya S/s Top/su - Noos 14067404...
# 4                      s.Oliver Dames  T-shirt  - Maat 34
# ...

# %% [markdown]
# The dataset contains 132,971 entries and 8 columns, as follows:
#
#     global_id: Unique identifier for each entry (int64).
#     chunk_name: General category or type of item (object).
#     title: Title or name of the item (object).
#     description: Description of the item, which may contain HTML tags (object).
#     colour: Colour of the item (object).
#     eu_size: European size of the item, if applicable (object).
#     dropdown_size: Another size attribute, likely in a different format or for different types of items (object, with mixed types warning).
#     number_of_products_in_package: Indicates how many items are included in the package, if this is a multi-item package (float64).

# %%
# Display the first few rows of the dataframe and basic information about the dataset
data_info = df.info()
data_head = df.head()

data_info, data_head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132971 entries, 0 to 132970
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   global_id                      132971 non-null  int64
#  1   chunk_name                     132971 non-null  object
#  2   title                          132969 non-null  object
#  3   description                    132964 non-null  object
#  4   colour                         132950 non-null  object
#  5   eu_size                        93404 non-null   object
#  6   dropdown_size                  20838 non-null   object
#  7   number_of_products_in_package  19288 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 8.1+ MB
# (None,
#            global_id chunk_name  \
#  0  9300000080997844    T-shirt
#  1  9300000050432315    T-shirt
#  2  9300000091408544    T-shirt
#  3  9300000096674994    T-shirt
# ...

# %% [markdown]
# Missing Values
#
#     Title: 2 missing values.
#     Description: 6 missing values.
#     Colour: 19 missing values.
#     EU Size: 39,567 missing values, indicating that this information is not available for a significant portion of the items.
#     Dropdown Size: 112,133 missing values, suggesting that this field is only used for a small subset of items.
#     Number of Products in Package: 113,683 missing values, indicating that the majority of items do not specify this information, possibly because they are sold individually.

# %%
import matplotlib.pyplot as plt

# Iterate over the columns of the DataFrame
for column in df.columns:
    # Plot a histogram for the column
    df[column].hist()
    # Set the title of the histogram as the column name
    plt.title(column)
    # Display the histogram
    plt.show()
# Out:
# /home/borna/DC/DCIAProject/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/borna/DC/DCIAProject/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/borna/DC/DCIAProject/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/borna/DC/DCIAProject/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/borna/DC/DCIAProject/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
# ...
